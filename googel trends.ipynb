# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/davidrothschild/DataspellProjects/Text-Mininig-Class/Final Project/multiTimeline-5.csv', skiprows=1)

# %%
df.head()
# Out:
#         Woche Truth Social: (Weltweit)
# 0  2021-03-07                        0
# 1  2021-03-14                        0
# 2  2021-03-21                        0
# 3  2021-03-28                        0
# 4  2021-04-04                        0

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(data.index, data.iloc[:, 0], marker='o')
plt.xticks(rotation=45)
plt.title('Trend Over Time for Truth Social: (Weltweit)')
plt.xlabel('Week')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
